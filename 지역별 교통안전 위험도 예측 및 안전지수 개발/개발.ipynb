# %%
import pandas as pd

festival = pd.read_csv('data/전국문화축제표준데이터.csv', encoding='cp949')

# %%
festival.head()
# Out:
#         축제명                    개최장소      축제시작일자      축제종료일자  \
# 0    구미라면축제                  구미역 일원  2026-11-06  2026-11-08
# 1    김천김밥축제      직지문화공원 및 사명대사공원 일원  2026-10-23  2026-10-25
# 2   임실N치즈축제  임실치즈테마파크+임실치즈마을+임실읍 일원  2026-10-08  2026-10-11
# 3  여주오곡나루축제            여주 신륵사관광지 일원  2026-10-23  2026-10-25
# 4  강동선사문화축제               서울 암사동 유적  2026-10-16  2026-10-18
#
#                                                 축제내용         주관기관명  \
# 0                   이색라면 레스토랑 및 `갓 튀긴 라면` 팝업스토어 운영 등      경상북도 구미시
# 1                           김밥플레이리스트(축하공연)+꼬달이 돌잡이 등      경상북도 김천시
# 2          임실N치즈 쭉쭉늘려 내치즈+디저트 퐁뒤체험+국가대표 임실N치즈 대형 쌀피자  임실N치즈축제제전위원회
# 3  여주쌀 가마솥 비빔밥+군고구마 기네스+여주 본두리 낙화놀이+여주 흔암리 쌍용거 줄다...    여주세종문화관광재단
# 4  개폐막식+축하공연+개막 드론쇼+폐막 불꽃쇼+거리퍼레이드+강동선사 노래자랑+자치회관 ...     서울특별시 강동구
#
#           주최기관명                                       후원기관명          전화번호  \
# 0      경상북도 구미시                                         NaN  054-480-2652
# ...

# %%
car_ = pd.read_csv('data/자동차등록현황보고_자동차등록대수현황 시도별 2026.csv', encoding='utf-8')
car_.head()
# Out:
#   월(Monthly) 시도명  시군구 관용(승용)  자가용(승용) 영업용(승용)    계(승용) 관용(승합) 자가용(승합) 영업용(승합)  \
# 0     26-Jun  서울  강남구    156  218,199  11,422  229,777     58   3,612     557
# 1     26-Jun  서울  강동구    109  145,492   4,952  150,553     41   2,930     601
# 2     26-Jun  서울  강북구    116   59,214   2,116   61,446     65   1,834     710
# 3     26-Jun  서울  강서구    136  166,615  11,053  177,804     44   3,665   1,385
# 4     26-Jun  서울  관악구     88   98,069   3,106  101,263     44   2,519     360
#
#    ... 영업용(화물)   계(화물) 관용(특수) 자가용(특수) 영업용(특수)  계(특수) 관용(총계)  자가용(총계) 영업용(총계)  \
# 0  ...   2,052  15,686     16     396     147    559    422  235,649  14,178
# 1  ...   2,574  14,525      8     273     201    482    307  160,497   8,328
# 2  ...   1,224   7,763     17     138     112    267    327   67,596   4,162
# 3  ...   4,364  19,882     18     486     258    762    355  186,127  17,060
# 4  ...   2,204  10,787     12     204     168    384    286  109,233   5,838
#
#      계(총계)
# 0  250,249
# ...

# %%
public_traffic = pd.read_csv('data/국내 지역별 문화향유를 위한 대중교통 시설 데이터.csv')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2628\124824426.py:1: DtypeWarning: Columns (0: branch_nm, 1: rd_nm, 2: bld_num) have mixed types. Specify dtype option on import or set low_memory=False.
#   public_traffic = pd.read_csv('data/국내 지역별 문화향유를 위한 대중교통 시설 데이터.csv')

# %%
public_traffic.head()
# Out:
#                     id lclas mlsfc    id_poi         poi_nm branch_nm  sub_nm  \
# 0  KCLPPPO25N000000001    장소    교통  10000524         잠두봉선착장       NaN     NaN
# 1  KCLPPPO25N000000002    장소    교통  10007331         대전조차장역       NaN     NaN
# 2  KCLPPPO25N000000003    장소    교통  10013282        고양종합터미널       NaN     NaN
# 3  KCLPPPO25N000000004    장소    교통  10066131       한국클린씨터미날       NaN     NaN
# 4  KCLPPPO25N000000005    장소    교통  10103445  부산철도차량정비단고속기지       NaN     NaN
#
#    mcate_cd   mcate_nm           pnu  ...         rd_cd rd_nm bld_num  \
# 0    150206  기타선착장/나루터  1.144012e+18  ...           NaN   NaN     NaN
# 1    150303     기타철도역명  3.023010e+18  ...  3.023030e+11  아리랑로     166
# 2    150501    고속버스터미널  4.128511e+18  ...  4.128532e+11   중앙로    1036
# 3    150503   화물/기타터미널  4.833025e+18  ...  4.833033e+11   제방로     345
# 4    150404       차량기지  2.623011e+18  ...  2.623021e+11  신천대로     215
#
#             x          y   grid_cd  lst_updt_dt  data_orgn  \
# ...
