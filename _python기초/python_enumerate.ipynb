# %% [markdown]
# ## 리스트의 for문

# %%
pandas = ['러바오','아이바오','푸바오','루이바오','후이바오']

# %%
for p in pandas:
    print(p)
# Out:
# 러바오
# 아이바오
# 푸바오
# 루이바오
# 후이바오

# %%
for i, p in enumerate(pandas):
    print(i,p)
# Out:
# 0 러바오
# 1 아이바오
# 2 푸바오
# 3 루이바오
# 4 후이바오
