# %% [markdown]
# # CSV 파일 읽기

# %%
result_list = []

with open('./covid.csv','r') as f:
    while True:
        line = f.readline()
    
        if not line:
            break
        result = line.split(',')
        result_list.append(result)

print(result_list)
# Out:
# [['항목', '사례수', '증가', '감소', '변화없음\n'], ['스마트폰', '999', '78.9', '1.7', '19.4\n'], ['텔레비전', '965', '68.5', '3.9', '27.6\n'], ['개인용 PC', '973', '65.7', '3.7', '30.6\n'], ['태블릿 PC', '662', '46.8', '4.2', '49\n'], ['라디오', '687', '35.5', '12.5', '52\n'], ['잡지·책', '776', '31.3', '17.8', '50.9\n'], ['종이신문', '552', '17.6', '23.2', '59.2\n']]

# %%
result_list = []

with open('./covid.csv','r') as f:
    f.readline()
    while True:
        line = f.readline()
    
        if not line:
            break
        result = line.split(',')
        result_list.append(result)

print(result_list)
# Out:
# [['스마트폰', '999', '78.9', '1.7', '19.4\n'], ['텔레비전', '965', '68.5', '3.9', '27.6\n'], ['개인용 PC', '973', '65.7', '3.7', '30.6\n'], ['태블릿 PC', '662', '46.8', '4.2', '49\n'], ['라디오', '687', '35.5', '12.5', '52\n'], ['잡지·책', '776', '31.3', '17.8', '50.9\n'], ['종이신문', '552', '17.6', '23.2', '59.2\n']]
